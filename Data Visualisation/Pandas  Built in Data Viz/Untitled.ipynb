# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
df1= pd.read_csv('df1',index_col=0)

# %%
 df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2= pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=20)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['A'].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c1407f8c97dc> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 plt.style.use('ggplot')
# ----> 3 df1['A'].hist()
#
# NameError: name 'df1' is not defined

# %%
df1['A'].plot.hist()

# %%
Adf2.plot.area(alpha=0.5)

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)

# %%
f = plt.figure()
df1.ix[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# Out:
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-fab6b95e1428> in <module>()
#       1 f = plt.figure()
# ----> 2 df1.ix[0:30].plot.area(alpha=0.4,ax=f.gca())
#       3 plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#       4 plt.show()
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in area(self, x, y, **kwds)
#    2807         axes : matplotlib.AxesSubplot or np.array of them
#    2808         """
# -> 2809         return self(kind='area', x=x, y=y, **kwds)
#    2810
#    2811     def pie(self, y=None, **kwds):
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2671                           fontsize=fontsize, colormap=colormap, table=table,
#    2672                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2673                           sort_columns=sort_columns, **kwds)
#    2674     __call__.__doc__ = plot_frame.__doc__
#    2675
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1898                  yerr=yerr, xerr=xerr,
#    1899                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1900                  **kwds)
#    1901
#    1902
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1725         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1726
# -> 1727     plot_obj.generate()
#    1728     plot_obj.draw()
#    1729     return plot_obj.result
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     252         self._compute_plot_data()
#     253         self._setup_subplots()
# --> 254         self._make_plot()
#     255         self._add_table()
#     256         self._make_legend()
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#     973                              stacking_id=stacking_id,
#     974                              is_errorbar=is_errorbar,
# --> 975                              **kwds)
#     976             self._add_legend_handle(newlines[0], label, index=i)
#     977
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1101         if column_num == 0:
#    1102             cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1103         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
#    1104
#    1105         # need to remove label, because subplots uses mpl legend as it is
#
# c:\users\arpit jain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py in _get_stacked_values(cls, ax, stacking_id, values, label)
#    1050                          'all positive or negative.'
#    1051                          '{0} contains both positive and negative values'
# -> 1052                          .format(label))
#    1053
#    1054     @classmethod
#
# ValueError: When stacked is True, each column must be either all positive or negative.A contains both positive and negative values
